# %% [markdown]
# # **Caso de Estudio: Optimización del Triaje Preventivo en el Hospital General de "San Carlos" 👨‍⚕️**
#
# ### 1. El Escenario Hospitalario
# El **Hospital General de San Carlos**, una institución de referencia en atención neurológica, se enfrenta a un desafío operativo crítico. En el último año, el servicio de urgencias ha registrado un aumento del **20% en ingresos por accidentes cerebrovasculares (ACV)**. Lo alarmante es que gran parte de estos pacientes habían asistido a consultas externas meses antes, pero sus factores de riesgo no fueron detectados de manera integral por el personal médico debido a la alta carga de pacientes.
#
# <center><img src = "img/img1.png" width = 400 height = 400></center>
#
# ### 2. La Problemática Médica
# La dirección médica ha identificado que el diagnóstico clínico tradicional se basa en umbrales aislados (como la presión arterial o la glucosa), ignorando la **interacción compleja** entre factores como el tipo de trabajo, el estado de fumador y el IMC.
#
# El hospital necesita una herramienta de **analítica predictiva** que funcione como una "alerta temprana". Sin embargo, el departamento de Ciencia de Datos del hospital ha reportado un problema técnico mayor: **la base de datos histórica es extremadamente desbalanceada**. De miles de registros, solo una pequeña fracción corresponde a casos positivos de infarto, lo que hace que los algoritmos estándar "subestimen" el riesgo real de los pacientes nuevos.
#
# ### 3. Requerimientos del Negocio
# Para que el hospital apruebe la implementación de este modelo, la solución debe cumplir con:
#
# * **Priorización de la Sensibilidad (Recall):** No podemos permitirnos clasificar a un paciente de alto riesgo como "sano". El costo de un falso negativo es una vida humana o una discapacidad permanente.
# * **Interpretabilidad:** Los médicos deben entender por qué el modelo asigna un alto riesgo a un paciente (ej. ¿Es por la edad combinada con el nivel de glucosa?).
# * **Manejo de Incertidumbre:** El sistema debe ser capaz de procesar registros con datos faltantes (como el IMC) sin perder fiabilidad.
#
# ### 4. Objetivo del Científico de Datos
# La misión será desarrollar un pipeline de Machine Learning que, partiendo de los datos crudos del hospital, limpie la información, aplique técnicas de **rebalanceo de clases (SMOTE/ADASYN)** y entregue un modelo predictivo capaz de alertar al personal médico con una confianza estadística superior a los métodos de triaje actuales.
