# %%
import pandas as pd

a = pd.read_csv("healthcare-dataset-stroke-transformed.csv")

# %%
a["smoking_status"].value_counts()
# Out:
# smoking_status
# never smoked    1892
# ever_smoked     1673
# Unknown         1544
# Name: count, dtype: int64

# %%
a["work_type"].value_counts()
# Out:
# work_type
# Private          2946
# Self-employed     819
# children          687
# Govt_job          657
# Name: count, dtype: int64
